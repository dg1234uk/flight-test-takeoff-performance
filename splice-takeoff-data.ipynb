# %% [markdown]
# # Get Take off data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv("./data/csv/5Nov24-flight1.csv")

# df_takeoff = df[511:540]

# plt.plot(df_takeoff["altitude_ft"])
# plt.show()
# plt.plot(df_takeoff["speed_kts"])
# plt.show()

# df_takeoff.to_csv("./data/csv/5Nov24-flight1-takeoff.csv")

# %%
# df = pd.read_csv("./data/csv/6Nov24-flight2.csv")

# df_takeoff = df[192:222]

# plt.plot(df_takeoff["altitude_ft"])
# plt.show()
# plt.plot(df_takeoff["speed_kts"])
# plt.show()

# df_takeoff.to_csv("./data/csv/6Nov24-flight2-takeoff.csv")
# df_takeoff

# %%
# df = pd.read_csv("./data/csv/6Nov24-flight3.csv")

# df_takeoff = df[436:466]

# plt.plot(df_takeoff["altitude_ft"])
# plt.show()
# plt.plot(df_takeoff["speed_kts"])
# plt.show()

# df_takeoff.to_csv("./data/csv/6Nov24-flight3-takeoff.csv")
# df_takeoff

# %%
# df = pd.read_csv("./data/csv/6Nov24-flight4.csv")

# df_takeoff = df[560:587]

# plt.plot(df_takeoff["altitude_ft"])
# plt.show()
# plt.plot(df_takeoff["speed_kts"])
# plt.show()

# df_takeoff.to_csv("./data/csv/6Nov24-flight4-takeoff.csv")
# df_takeoff

# %%
# df = pd.read_csv("./data/csv/7Nov24-flight5.csv")

# df_takeoff = df[445:475]

# plt.plot(df_takeoff["altitude_ft"])
# plt.show()
# plt.plot(df_takeoff["speed_kts"])
# plt.show()

# df_takeoff.to_csv("./data/csv/7Nov24-flight5-takeoff.csv")
# df_takeoff
# Out:
#                    timestamp   latitude   longitude  altitude_m  acc_horiz  \
# 445  2024-11-07T16:26:00.25Z  40.718980 -114.042558      1294.7        0.0
# 446  2024-11-07T16:26:01.44Z  40.718981 -114.042546      1294.8        0.0
# 447  2024-11-07T16:26:02.84Z  40.718981 -114.042466      1294.9        0.0
# 448  2024-11-07T16:26:03.46Z  40.718982 -114.042408      1295.0        0.0
# 449  2024-11-07T16:26:04.84Z  40.718984 -114.042222      1295.1        0.0
# 450  2024-11-07T16:26:05.44Z  40.718984 -114.042119      1295.1        0.0
# 451  2024-11-07T16:26:06.84Z  40.718986 -114.041827      1295.2        0.0
# 452  2024-11-07T16:26:07.44Z  40.718986 -114.041679      1295.3        0.0
# 453  2024-11-07T16:26:08.84Z  40.718986 -114.041282      1295.3        0.0
# 454  2024-11-07T16:26:09.44Z  40.718985 -114.041090      1295.3        0.0
# 455  2024-11-07T16:26:10.84Z  40.718984 -114.040593      1295.3        0.0
# ...
